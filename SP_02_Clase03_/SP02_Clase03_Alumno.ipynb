# %% [markdown]
# <h1>Tabla de Contenidos<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#OPERACIONES-CON-COLUMNAS-O-FILAS" data-toc-modified-id="OPERACIONES-CON-COLUMNAS-O-FILAS-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>OPERACIONES CON COLUMNAS O FILAS</a></span><ul class="toc-item"><li><span><a href="#Multiplicar-una-columna-por-un-número" data-toc-modified-id="Multiplicar-una-columna-por-un-número-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Multiplicar una columna por un número</a></span></li><li><span><a href="#Suma-o-resta-de-columnas" data-toc-modified-id="Suma-o-resta-de-columnas-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Suma o resta de columnas</a></span></li><li><span><a href="#Multiplicación-y-División-de-columnas" data-toc-modified-id="Multiplicación-y-División-de-columnas-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Multiplicación y División de columnas</a></span></li><li><span><a href="#Potencia-pow(elemento,-potencia)" data-toc-modified-id="Potencia-pow(elemento,-potencia)-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Potencia pow(elemento, potencia)</a></span></li><li><span><a href="#Exponencial" data-toc-modified-id="Exponencial-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Exponencial</a></span></li></ul></li><li><span><a href="#Eliminar-columnas-con-drop" data-toc-modified-id="Eliminar-columnas-con-drop-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Eliminar columnas con drop</a></span></li><li><span><a href="#Filtros-en-Pandas" data-toc-modified-id="Filtros-en-Pandas-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Filtros en Pandas</a></span></li><li><span><a href="#FORMAS-DE-ORDENAR" data-toc-modified-id="FORMAS-DE-ORDENAR-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>FORMAS DE ORDENAR</a></span><ul class="toc-item"><li><span><a href="#Ordenando-las-filas-por-los-valores-de-una-columna" data-toc-modified-id="Ordenando-las-filas-por-los-valores-de-una-columna-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Ordenando las filas por los valores de una columna</a></span></li><li><span><a href="#Ordenando-las-filas-por-los-valores-de-varias-columnas:" data-toc-modified-id="Ordenando-las-filas-por-los-valores-de-varias-columnas:-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Ordenando las filas por los valores de varias columnas:</a></span></li></ul></li></ul></div>

# %% [markdown]
# ![IES21](img/logo_ies.png)

# %% [markdown]
# # COMPUTACIÓN CIENTÍFICA
# # Situación Profesional 2
# # Clase 3: Pandas
# **Prof. Ricardo Piña**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## OPERACIONES CON COLUMNAS O FILAS

# %% [markdown]
# Carguemos el archivo csv iris.tab en un dataframe de nombre df_iris

# %%
df_iris=pd.read_csv("data/iris.tab",sep='\t',skiprows=(1,2))
df_iris.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-5520d762077b> in <module>
# ----> 1 df_iris=pd.read_csv("data/iris.tab",sep='\t',skiprows=(1,2))
#       2 df_iris.head()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %% [markdown]
# Cambie los nombres para que no tengan espacios ...

# %%
# Escriba aquí su código
df_iris.columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'iris']

# %%
df_iris.info()

# %% [markdown]
# ### Multiplicar una columna por un número

# %% [markdown]
# Supongamos que necesitamos multiplicar por 2 la columna sepal_length, entonces simplemente hacemos:
# columna * 2

# %%
df_iris.sepal_length*2

# %% [markdown]
# Compare con la impresión del dataframe que hicimos antes y podrá verificar que los valores de la columna efectivamente han sido multiplicados por 2, **aunque estos cambios no sea han efectuado en el dataframe**, fijese:

# %%
df_iris.head()

# %% [markdown]
# Si quisiéramos que se cambiara la columna, deberíamos asignarle el resultado obtenido. En este caso no deseamos hacerlo.

# %% [markdown]
# ### Suma o resta de columnas
#
# **columna + columna**
# **columna - columna**

# %% [markdown]
# Supongamos que necesitamos restar sepal_length - petal_length, simplemente podemos hacer lo siguiente:

# %%
df_iris.sepal_length - df_iris.petal_length

# %% [markdown]
# De la misma manera que indicábamos con anterioridad, este resultado no se encuentra en el dataframe.
# Esta vez sí supongamos que deseamos **agregarlo** como una columna más del dataframe con el nombre de 'sl-pl'.

# %%
df_iris['sl-pl']=df_iris.sepal_length - df_iris.petal_length
df_iris

# %% [markdown]
# ### Multiplicación y División de columnas
#
# **columna * columna**
# **columna/columna**

# %% [markdown]
# En un caso como el del reconocimiento de la flor Iris por Machine Learning, seguramente sería de interés tener en una feature o variable con una aproximación a la superficie de los pétalos.
#
# Agregue esta columna con el nombre 'sup-pet'

# %%
# Escriba aquí su código
df_iris["sup-pet"]=df_iris.petal_length * df_iris.petal_width
df_iris
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2dba037ab2ac> in <module>
#       1 # Escriba aquí su código
# ----> 2 df_iris["sup-pet"]=df_iris.petal_length * df_iris.petal_width
#       3 df_iris
#
# NameError: name 'df_iris' is not defined

# %% [markdown]
# Podríamos hacer lo mismo para los sépalos .. guárdelo en la columna 'sup-sep'

# %%
# Escriba aquí su código
# Out:
#    sepal_length  sepal_width  petal_length  petal_width         iris  sl-pl  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa    3.7
# 1           4.9          3.0           1.4          0.2  Iris-setosa    3.5
# 2           4.7          3.2           1.3          0.2  Iris-setosa    3.4
# 3           4.6          3.1           1.5          0.2  Iris-setosa    3.1
# 4           5.0          3.6           1.4          0.2  Iris-setosa    3.6
#
#    sup-pet  sup-sep
# 0     0.28    17.85
# 1     0.28    14.70
# 2     0.26    15.04
# 3     0.30    14.26
# 4     0.28    18.00

# %% [markdown]
# Seguro que un problema de identificación de flores de las cuales conocemos las medidas, las relaciones entre las medidas también sería importantes, así que creemos una nueva variable llamada 'pet_l/pet_w' cuyos valores sean  la división de petal_length sobre petal_width.

# %%
# Escriba aquí su código
# Out:
#    sepal_length  sepal_width  petal_length  petal_width         iris  sl-pl  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa    3.7
# 1           4.9          3.0           1.4          0.2  Iris-setosa    3.5
# 2           4.7          3.2           1.3          0.2  Iris-setosa    3.4
# 3           4.6          3.1           1.5          0.2  Iris-setosa    3.1
# 4           5.0          3.6           1.4          0.2  Iris-setosa    3.6
#
#    sup-pet  sup-sep  pet_l/pet_w
# 0     0.28    17.85          7.0
# 1     0.28    14.70          7.0
# 2     0.26    15.04          6.5
# 3     0.30    14.26          7.5
# 4     0.28    18.00          7.0

# %% [markdown]
# ### Potencia pow(elemento, potencia)
# También podríamos elevar al cuadrado, al cubo o a la n los valores de alguna columna ...

# %% [markdown]
# Eleve al cuadrado los valores de petal_length, no los agregue al dataframe.

# %%
pow(df_iris.petal_length,2)
# Out:
# 0       1.96
# 1       1.96
# 2       1.69
# 3       2.25
# 4       1.96
#        ...
# 145    27.04
# 146    25.00
# 147    27.04
# 148    29.16
# 149    26.01
# Name: petal_length, Length: 150, dtype: float64

# %%
df_iris.petal_length**2
# Out:
# 0       1.96
# 1       1.96
# 2       1.69
# 3       2.25
# 4       1.96
#        ...
# 145    27.04
# 146    25.00
# 147    27.04
# 148    29.16
# 149    26.01
# Name: petal_length, Length: 150, dtype: float64

# %% [markdown]
# Las raíces también pueden calcularse como potencia.

# %% [markdown]
# ### Exponencial
# $$ e^c $$
#
# Daría por resultado cada elemento de la columna como exponente de e.

# %%
np.exp(df_iris.petal_length)   # tuve que usar np.exp() porque de otra manera no me andaba, verifique.
# Out:
# 0        4.055200
# 1        4.055200
# 2        3.669297
# 3        4.481689
# 4        4.055200
#           ...
# 145    181.272242
# 146    148.413159
# 147    181.272242
# 148    221.406416
# 149    164.021907
# Name: petal_length, Length: 150, dtype: float64

# %% [markdown]
# ## Eliminar columnas con drop

# %% [markdown]
# Supongamos que queremos eliminar la columna sl-pl que creamos hacer un rato, podemos usar .drop:
#
# documentación en: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html

# %%
df_iris.drop('sl-pl',axis=1).head() # axis=1 para eliminar la columna.

# también se podría haber usado:
# df_iris.drop(columns=['sl-pl'])  y evitamos recordar el axis!
# Out:
#    sepal_length  sepal_width  petal_length  petal_width         iris  sup-pet  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa     0.28
# 1           4.9          3.0           1.4          0.2  Iris-setosa     0.28
# 2           4.7          3.2           1.3          0.2  Iris-setosa     0.26
# 3           4.6          3.1           1.5          0.2  Iris-setosa     0.30
# 4           5.0          3.6           1.4          0.2  Iris-setosa     0.28
#
#    sup-sep  pet_l/pet_w
# 0    17.85          7.0
# 1    14.70          7.0
# 2    15.04          6.5
# 3    14.26          7.5
# 4    18.00          7.0

# %% [markdown]
# ## Filtros en Pandas

# %% [markdown]
# Los filtros de tipo **.filter** en Pandas **NO** se usan para filtrar por el valor de los ítems (las celdas de Excel), sino que se utilizan para **filtrar por los valores o etiquetas de los índices de las columnas o de las filas**. No los veremos por el momento.
#
# Documentación: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.filter.html

# %% [markdown]
# Nuestro interés está en el proceso de **filtrado por valores de los items** y en este sentido es muy similar al funcionamiento de NumPy.
#
# En la jerga de Pandas en vez de filtrado se suele denominar como
#
# *__obtención de subconjuntos de filas que, por ejemplo, verifican cierto criterio__*.

# %% [markdown]
# Recordemos qué tenemos en nuestro dataframe:

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width         iris  sl-pl  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa    3.7
# 1           4.9          3.0           1.4          0.2  Iris-setosa    3.5
# 2           4.7          3.2           1.3          0.2  Iris-setosa    3.4
# 3           4.6          3.1           1.5          0.2  Iris-setosa    3.1
# 4           5.0          3.6           1.4          0.2  Iris-setosa    3.6
#
#    sup-pet  sup-sep  pet_l/pet_w
# 0     0.28    17.85          7.0
# 1     0.28    14.70          7.0
# 2     0.26    15.04          6.5
# 3     0.30    14.26          7.5
# 4     0.28    18.00          7.0

# %% [markdown]
# Supongamos que deseamos ver todas las filas para las cuales el valor de sepal_length sea menor que 5.
# El procedimiento será muy similar al del NumPy.

# %%
df_iris[df_iris.sepal_length < 5]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width             iris  \
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 11            4.8          3.4           1.6          0.2      Iris-setosa
# 12            4.8          3.0           1.4          0.1      Iris-setosa
# 13            4.3          3.0           1.1          0.1      Iris-setosa
# 22            4.6          3.6           1.0          0.2      Iris-setosa
# 24            4.8          3.4           1.9          0.2      Iris-setosa
# ...

# %% [markdown]
# Obtengamos las filas para las cuales el valor de sepal_length sea mayor que el doble del sepal_width

# %%
#Escriba aqui su código
# Out:
#      sepal_length  sepal_width  petal_length  petal_width             iris  \
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# 55            5.7          2.8           4.5          1.3  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 143           6.8          3.2           5.9          2.3   Iris-virginica
# 144           6.7          3.3           5.7          2.5   Iris-virginica
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
#
#      sl-pl  sup-pet  sup-sep  pet_l/pet_w
# ...

# %% [markdown]
# Lo mismo que antes pero muestre sólo esas dos columnas y la columna iris

# %%
# Escriba aqui su código
# Out:
#      sepal_length  sepal_width             iris
# 50            7.0          3.2  Iris-versicolor
# 52            6.9          3.1  Iris-versicolor
# 53            5.5          2.3  Iris-versicolor
# 54            6.5          2.8  Iris-versicolor
# 55            5.7          2.8  Iris-versicolor
# ..            ...          ...              ...
# 143           6.8          3.2   Iris-virginica
# 144           6.7          3.3   Iris-virginica
# 145           6.7          3.0   Iris-virginica
# 146           6.3          2.5   Iris-virginica
# 147           6.5          3.0   Iris-virginica
#
# [79 rows x 3 columns]

# %% [markdown]
# Muestre qué valores **distintos** se han cargado en la columna iris.

# %%
#Escriba aquí su código
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# Queremos todas las filas para las cuales en la columna iris dice Iris-virginica. Muestre sólo las primeras 4

# %%
# Escriba aquí su código
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            iris  \
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
#
#      sl-pl  sup-pet  sup-sep  pet_l/pet_w
# 100    0.3    15.00    20.79     2.400000
# 101    0.7     9.69    15.66     2.684211
# 102    1.2    12.39    21.30     2.809524
# 103    0.7    10.08    18.27     3.111111

# %% [markdown]
# Cuando tenemos valores de cadena de texto suele ser útil el uso de:
#
# **columna.str.contains('cadena_de_caracteres')**
#
# Queremos todas las filas para las cuales en el texto cargado en la columna iris contiene v.

# %%
# Escriba aquí su código
# Out:
#      sepal_length  sepal_width  petal_length  petal_width             iris  \
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
#      sl-pl  sup-pet  sup-sep  pet_l/pet_w
# ...

# %% [markdown]
# Queremos todas las filas para las cuales en el texto cargado en la columna iris contiene v y contiene la cadena 'color'

# %%
df_iris[(df_iris.iris.str.contains('v')) & (df_iris.iris.str.contains('color'))]  # con and nos dio error
# Out:
#     sepal_length  sepal_width  petal_length  petal_width             iris  \
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 53           5.5          2.3           4.0          1.3  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor
# 55           5.7          2.8           4.5          1.3  Iris-versicolor
# 56           6.3          3.3           4.7          1.6  Iris-versicolor
# 57           4.9          2.4           3.3          1.0  Iris-versicolor
# 58           6.6          2.9           4.6          1.3  Iris-versicolor
# 59           5.2          2.7           3.9          1.4  Iris-versicolor
# 60           5.0          2.0           3.5          1.0  Iris-versicolor
# 61           5.9          3.0           4.2          1.5  Iris-versicolor
# ...

# %% [markdown]
# Queremos todas las filas para las cuales en el texto cargado en la columna iris contiene v o  contiene la cadena 'color'.

# %%
df_iris[(df_iris.iris.str.contains('v')) | (df_iris.iris.str.contains('color'))]  # con or nos dio error
# Out:
#      sepal_length  sepal_width  petal_length  petal_width             iris  \
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
#      sl-pl  sup-pet  sup-sep  pet_l/pet_w
# ...

# %% [markdown]
# Obviamente que
# **columna.str.contains('cadena_de_caracteres')**
#
# puede usarse con más de una caracter. En este caso buscará la cadena en cualquier parte del texto que figure en cada una de las celdas de esa columna.
#
# Si necesitamos una expresión más exacta, podemos usar **regex**, que tiene sus complicaciones, pero por ahora no entraremos en esos detalles.

# %% [markdown]
# Queremos todas las filas en las cuales el valor de iris contenga la cadena 'color'. Muestre sólo los últimos 4 registros

# %%
# Escriba aquí su código
# Out:
#     sepal_length  sepal_width  petal_length  petal_width             iris  \
# 96           5.7          2.9           4.2          1.3  Iris-versicolor
# 97           6.2          2.9           4.3          1.3  Iris-versicolor
# 98           5.1          2.5           3.0          1.1  Iris-versicolor
# 99           5.7          2.8           4.1          1.3  Iris-versicolor
#
#     sl-pl  sup-pet  sup-sep  pet_l/pet_w
# 96    1.5     5.46    16.53     3.230769
# 97    1.9     5.59    17.98     3.307692
# 98    2.1     3.30    12.75     2.727273
# 99    1.6     5.33    15.96     3.153846

# %% [markdown]
# Queremos todas las filas cuyo texto en la columna iris no contenga la cadena *color*. Muestre las últimas 3 filsa.
#
# **Nota:** no existe el método "notcontains", asi que podría usar la idea de  negar el resultado de contains. Puede hacerlo de dos maneras usando **~** que es el operador para __negación__, o bien imponiendo en la condición que el resultado de contains()==False.

# %%
df_iris[ ~df_iris.iris.str.contains('color')].tail(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            iris  \
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      sl-pl  sup-pet  sup-sep  pet_l/pet_w
# 147    1.3    10.40    19.50     2.600000
# 148    0.8    12.42    21.08     2.347826
# 149    0.8     9.18    17.70     2.833333

# %% [markdown]
# Queremos todas las filas para las cuales sepal_length es mayor a 4, petal_lenght menor a 3 y el texto cargado en iris no contiene la cadena color. Muestre las primeras 6 filas.
#
#
# Nota: use & para la operación lógica y en vez de and, suele ser necesario separar las pruebas lógicas escribiéndolas entre paréntesis.

# %%
# Escriba aquí su código
# Out:
#    sepal_length  sepal_width  petal_length  petal_width         iris  sl-pl  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa    3.7
# 1           4.9          3.0           1.4          0.2  Iris-setosa    3.5
# 2           4.7          3.2           1.3          0.2  Iris-setosa    3.4
# 3           4.6          3.1           1.5          0.2  Iris-setosa    3.1
# 4           5.0          3.6           1.4          0.2  Iris-setosa    3.6
# 5           5.4          3.9           1.7          0.4  Iris-setosa    3.7
#
#    sup-pet  sup-sep  pet_l/pet_w
# 0     0.28    17.85         7.00
# 1     0.28    14.70         7.00
# 2     0.26    15.04         6.50
# 3     0.30    14.26         7.50
# 4     0.28    18.00         7.00
# 5     0.68    21.06         4.25

# %% [markdown]
# En la primer clase de Pandas vimos cómo calcular la media de los valores de una columna.

# %% [markdown]
# En qué observaciones el valor de sepal_length está por sobre la media? Muestre las 5 primeras filas.

# %%
# Escriba aquí su código
# Out:
#     sepal_length  sepal_width  petal_length  petal_width             iris  \
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor
# 56           6.3          3.3           4.7          1.6  Iris-versicolor
#
#     sl-pl  sup-pet  sup-sep  pet_l/pet_w
# 50    2.3     6.58    22.40     3.357143
# 51    1.9     6.75    20.48     3.000000
# 52    2.0     7.35    21.39     3.266667
# 54    1.9     6.90    18.20     3.066667
# 56    1.6     7.52    20.79     2.937500

# %% [markdown]
# Ahora queremos ver todas las filas para las cuales el valor de sepal_length está por sobre la media y los valores de sepal_width están por debajo de la media.

# %%
# Escriba aquí su código
# Out:
#     sepal_length  sepal_width  petal_length  petal_width             iris  \
# 54           6.5          2.8           4.6          1.5  Iris-versicolor
# 58           6.6          2.9           4.6          1.3  Iris-versicolor
# 61           5.9          3.0           4.2          1.5  Iris-versicolor
# 62           6.0          2.2           4.0          1.0  Iris-versicolor
# 63           6.1          2.9           4.7          1.4  Iris-versicolor
#
#     sl-pl  sup-pet  sup-sep  pet_l/pet_w
# 54    1.9     6.90    18.20     3.066667
# 58    2.0     5.98    19.14     3.538462
# 61    1.7     6.30    17.70     2.800000
# 62    2.0     4.00    13.20     4.000000
# 63    1.4     6.58    17.69     3.357143

# %% [markdown]
# Ahora queremos las filas en las cuales la media de sepal_length **o** la media de sepal_width están por sobre sus respectivas medias.

# %%
# Escriba aquí su código
# Out:
#    sepal_length  sepal_width  petal_length  petal_width         iris  sl-pl  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa    3.7
# 2           4.7          3.2           1.3          0.2  Iris-setosa    3.4
# 3           4.6          3.1           1.5          0.2  Iris-setosa    3.1
# 4           5.0          3.6           1.4          0.2  Iris-setosa    3.6
# 5           5.4          3.9           1.7          0.4  Iris-setosa    3.7
#
#    sup-pet  sup-sep  pet_l/pet_w
# 0     0.28    17.85         7.00
# 2     0.26    15.04         6.50
# 3     0.30    14.26         7.50
# 4     0.28    18.00         7.00
# 5     0.68    21.06         4.25

# %% [markdown]
# ## FORMAS DE ORDENAR

# %% [markdown]
# ### Ordenando las filas por los valores de una columna

# %% [markdown]
# Si queremos ordenar el dataframe por los valores de una fila, podemos usar:
#
# **DataFrame.sort_values()**
#
# Documentación: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html

# %% [markdown]
# En este caso es interesante observar sus argumentos, véalos en la documentación indicada.

# %% [markdown]
# Obtengamos un duplicado de df_iris, de tal forma que sus filas estén ordenadas por las columna iris en formas ascendente, es decir de a a la z.

# %%
df_iris.sort_values('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            iris  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 27            5.2          3.5           1.5          0.2     Iris-setosa
# 28            5.2          3.4           1.4          0.2     Iris-setosa
# 29            4.7          3.2           1.6          0.2     Iris-setosa
# 30            4.8          3.1           1.6          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 119           6.0          2.2           5.0          1.5  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 121           5.6          2.8           4.9          2.0  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      sl-pl  sup-pet  sup-sep  pet_l/pet_w
# ...

# %% [markdown]
# Obtengamos un duplicado de df_iris, de tal forma que sus filas estén ordenadas por las columna iris en formas descendente, es decir de la z a la a.

# %%
# Escriba aquí su código
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            iris  \
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 121           5.6          2.8           4.9          2.0  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# ..            ...          ...           ...          ...             ...
# 31            5.4          3.4           1.5          0.4     Iris-setosa
# 30            4.8          3.1           1.6          0.2     Iris-setosa
# 29            4.7          3.2           1.6          0.2     Iris-setosa
# 28            5.2          3.4           1.4          0.2     Iris-setosa
# 0             5.1          3.5           1.4          0.2     Iris-setosa
#
#      sl-pl  sup-pet  sup-sep  pet_l/pet_w
# ...

# %% [markdown]
# ### Ordenando las filas por los valores de varias columnas:

# %% [markdown]
# Cuando se ordena por los valores de varias columnas es importante tener en cuenta qué significa.
# Supongamos que tenemos un df con las columnas Apellido y Nombre y asumamos que queremos ordenarla por las columnas Apellido (primero) y (luego por ) las columna nombre.
#
# Esto significa que el ordenamiento principal será por Apellido y en el caso que "haya empate" en el valor del apellido, entonces desempatará con el valor de la columna Nombre.

# %% [markdown]
# Ordenar en forma ascentente a df_iris primero por la columna iris y luego por la columna sepal_length. Muestre los primero 6 casos. En este caso, cuando tenemos varias columnas para ordenar, debemos pasar los valores de las columnas como array.

# %%
df_iris.sort_values(by=[ 'iris','sepal_length']).head(6)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width         iris  sl-pl  \
# 13           4.3          3.0           1.1          0.1  Iris-setosa    3.2
# 8            4.4          2.9           1.4          0.2  Iris-setosa    3.0
# 38           4.4          3.0           1.3          0.2  Iris-setosa    3.1
# 42           4.4          3.2           1.3          0.2  Iris-setosa    3.1
# 41           4.5          2.3           1.3          0.3  Iris-setosa    3.2
# 3            4.6          3.1           1.5          0.2  Iris-setosa    3.1
#
#     sup-pet  sup-sep  pet_l/pet_w
# 13     0.11    12.90    11.000000
# 8      0.28    12.76     7.000000
# 38     0.26    13.20     6.500000
# 42     0.26    14.08     6.500000
# 41     0.39    10.35     4.333333
# 3      0.30    14.26     7.500000

# %% [markdown]
# Ahora ordene por las columnas iris, sepal_length y sepal_width, en ese orden.

# %%
# Escriba aquí su código

# %% [markdown]
# Qué pasará si queremos ordenar por una columna en forma ascendente y por otra en forma descendente?
# Ayuda, de la misma manera que podemos pasar varias columnas en un array, también podemos hacer lo mismo para el valor del  atributo **ascending** ...
#
# Ordene df_iris primero por la columna iris en forma descendente y luego por la columna sepal_length en forma ascendente. Muestre las 6 primeras filas.

# %%
# Escriba aquí su código
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            iris  \
# 106           4.9          2.5           4.5          1.7  Iris-virginica
# 121           5.6          2.8           4.9          2.0  Iris-virginica
# 113           5.7          2.5           5.0          2.0  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
#
#      sl-pl  sup-pet  sup-sep  pet_l/pet_w
# 106    0.4     7.65    12.25     2.647059
# 121    0.7     9.80    15.68     2.450000
# 113    0.7    10.00    14.25     2.500000
# 101    0.7     9.69    15.66     2.684211
# 114    0.7    12.24    16.24     2.125000
# 142    0.7     9.69    15.66     2.684211
